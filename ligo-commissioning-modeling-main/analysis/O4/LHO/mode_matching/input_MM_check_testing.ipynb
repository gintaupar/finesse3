# %% [markdown]
# Restarted finesseligo (Python 3.12.8)

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.solutions import SimpleSolution
from finesse_ligo.actions import InitialLockLIGO, DARM_RF_to_DC
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC

from POP_factory import POPWFSFactory, POPWFS_params

finesse.init_plotting()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      10 from finesse_ligo.actions import InitialLockLIGO, DARM_RF_to_DC
#      11 from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC
# ---> 13 from POP_factory import POPWFSFactory, POPWFS_params
#      15 finesse.init_plotting()
#
# ModuleNotFoundError: No module named 'POP_factory'

# %%
pwd
# Out:
# '/Users/ecapote/ligo-commissioning-modeling'

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.solutions import SimpleSolution
from finesse_ligo.actions import InitialLockLIGO, DARM_RF_to_DC
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC

#from POP_factory import POPWFSFactory, POPWFS_params

finesse.init_plotting()

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.solutions import SimpleSolution
from finesse_ligo.actions import InitialLockLIGO, DARM_RF_to_DC
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC

#from POP_factory import POPWFSFactory, POPWFS_params

from finesse.ligo.lho import make_O4_lho
from finesse.tracing.tree import TraceTree

finesse.init_plotting()

# %%
lho = make_O4_lho()
lho.ITMY.misaligned  = True
lho.ETMY.misaligned  = True
lho.ETMX.misaligned  = True
lho.IMC.priority = 1000
lho.cavXARM.priority = 1000-1

# %%
lho.IMC
# Out:
# <'IMC' @ 0x3032b7e30 (Gauss)>

# %%
lho.MC1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lho.MC1
#
# AttributeError: 'Model' object has no attribute 'MC1'

# %%
lho.IMC.MC1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 lho.IMC.MC1
#
# AttributeError: 'Gauss' object has no attribute 'MC1'

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC
from finesse_ligo.factory import ALIGOFactory

from finesse.ligo.lho import make_O4_lho
from finesse.tracing.tree import TraceTree

finesse.init_plotting()

# %%
factory = ALIGOFactory("lho_O4.yaml")

factory.options.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

#lho = make_O4_lho()
lho.ITMY.misaligned  = True
lho.ETMY.misaligned  = True
lho.ETMX.misaligned  = True
lho.IMC.priority = 1000
lho.cavXARM.priority = 1000-1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 13
#      11 lho.ETMY.misaligned  = True
#      12 lho.ETMX.misaligned  = True
# ---> 13 lho.IMC.priority = 1000
#      14 lho.cavXARM.priority = 1000-1
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
factory = ALIGOFactory("lho_O4.yaml")

factory.options.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

# %%
model.MC1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.MC1
#
# NameError: name 'model' is not defined

# %%
lho.MC1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 lho.MC1
#
# AttributeError: 'Model' object has no attribute 'MC1'

# %%
lho.IMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lho.IMC
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
lho.cavIMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 lho.cavIMC
#
# AttributeError: 'Model' object has no attribute 'cavIMC'

# %%
lho.Inout
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 lho.Inout
#
# AttributeError: 'Model' object has no attribute 'Inout'

# %%
lho.Input
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 lho.Input
#
# AttributeError: 'Model' object has no attribute 'Input'

# %%
lho.input
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lho.input
#
# AttributeError: 'Model' object has no attribute 'input'

# %%
lho.MC3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 lho.MC3
#
# AttributeError: 'Model' object has no attribute 'MC3'

# %%
lho.nodes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 lho.nodes
#
# AttributeError: 'Model' object has no attribute 'nodes'

# %%
lho.LASER
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 lho.LASER
#
# AttributeError: 'Model' object has no attribute 'LASER'

# %%
lho.ITMX
# Out:
# <'ITMX' @ 0x302725a30 (Mirror)>

# %%
lho.PRM
# Out:
# <'PRM' @ 0x303c0ac30 (Mirror)>

# %%
lho.IM1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lho.IM1
#
# AttributeError: 'Model' object has no attribute 'IM1'

# %%
lho.IM2
# Out:
# <'IM2' @ 0x303cd1970 (Beamsplitter)>

# %%
factory = ALIGOFactory("lho_O4.yaml")

#factory.options.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

# %%
lho.IM1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 lho.IM1
#
# AttributeError: 'Model' object has no attribute 'IM1'

# %%
lho.IM2
# Out:
# <'IM2' @ 0x303353e00 (Beamsplitter)>

# %%
factory = ALIGOFactory("lho_O4.yaml")

factory.options.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

# %%
lho.IMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 lho.IMC
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
lho.MC1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 lho.MC1
#
# AttributeError: 'Model' object has no attribute 'MC1'

# %%
lho.IMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 lho.IMC
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
lho.cavIMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 lho.cavIMC
#
# AttributeError: 'Model' object has no attribute 'cavIMC'

# %%
lho.MC2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 lho.MC2
#
# AttributeError: 'Model' object has no attribute 'MC2'

# %%
lho.MC3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 lho.MC3
#
# AttributeError: 'Model' object has no attribute 'MC3'

# %%
lho.IMC
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 lho.IMC
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
factory = ALIGOFactory("lho_O4.yaml")

factory.options.INPUT.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

# %%
#lho = make_O4_lho()
lho.ITMY.misaligned  = True
lho.ETMY.misaligned  = True
lho.ETMX.misaligned  = True
lho.IMC.priority = 1000
lho.cavXARM.priority = 1000-1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 7
#       5 lho.ETMY.misaligned  = True
#       6 lho.ETMX.misaligned  = True
# ----> 7 lho.IMC.priority = 1000
#       8 lho.cavXARM.priority = 1000-1
#
# AttributeError: 'Model' object has no attribute 'IMC'

# %%
lho.cavIMC
# Out:
# <'cavIMC' @ 0x3033a48f0 (Cavity)>

# %%
#lho = make_O4_lho()
lho.ITMY.misaligned  = True
lho.ETMY.misaligned  = True
lho.ETMX.misaligned  = True
lho.cavIMC.priority = 1000
lho.cavXARM.priority = 1000-1

# %%
lho.cavIMC.node
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 lho.cavIMC.node
#
# AttributeError: 'Cavity' object has no attribute 'node'

# %%
lho.cavIMC
# Out:
# <'cavIMC' @ 0x3033a48f0 (Cavity)>

# %%
lho.gausses
# Out:
# {}

# %%
lho.path(MC1.p4, MC3.p3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 lho.path(MC1.p4, MC3.p3)
#
# NameError: name 'MC1' is not defined

# %%
lho.path(lho.MC1.p4, lho.MC3.p3)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 lho.path(lho.MC1.p4, lho.MC3.p3)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3643, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3641 if via_node is None:
#    3642     try:
# -> 3643         path = nx.shortest_path(self.optical_network, from_node, to_node)
#    3644     except nx.exception.NetworkXNoPath:
#    3645         raise
#
# File <class 'networkx.utils.decorators.argmap'> compilation 34:3, in argmap_shortest_path_31(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...

# %%
lho.path(lho.MC1, lho.MC3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 lho.path(lho.MC1, lho.MC3)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3625, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3591 def path(self, from_node, to_node, via_node=None, symbolic=False):
#    3592     """Retrieves an ordered container of the path trace between the specified nodes.
#    3593
#    3594     The return type is an :class:`.OpticalPath` instance which stores an underlying
#    (...)   3623         If no path can be found between `from_node` and `to_node`.
#    3624     """
# -> 3625     from_node, to_node, via_node = self.__parse_path_nodes(
#    3626         from_node, to_node, via_node
#    3627     )
#    3629     try:
#    3630         self.__node_exists_check(from_node)
#
# ...

# %%
lho.path(lho.MC1.p2, lho.MC3.p1)

# %%
lho.propagate_beam(lho.MC1.p2, lho.MC3.p1)
# Out:
# <PropagationSolution of Propagation_MC1.p2.o_MC3.p1.i_x @ 0x3043030e0 children=0>

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1)

# %%
ps.plot
# Out:
# <bound method PropagationSolution.plot of <PropagationSolution of Propagation_MC1.p2.o_MC3.p1.i_x @ 0x304303070 children=0>>

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.PRM.p1)

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps = lho.path(lho.MC1.p2, lho.MC3.p1)

# %%
ps

# %%
ps.nodes
# Out:
# [<OpticalNode MC1.p2.o @ 0x302659880>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>]

# %%
ps = lho.path(lho.MC1.p2, lho.PRM.p1)

# %%
ps.nodes
# Out:
# [<OpticalNode MC1.p2.o @ 0x302659880>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>,
#  <OpticalNode MC3.p3.o @ 0x3040996d0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>,
#  <OpticalNode IM2.p2.o @ 0x302677530>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>,
#  <OpticalNode IM3.p1.i @ 0x302675580>,
#  <OpticalNode IM3.p2.o @ 0x302675a00>,
#  <OpticalNode IM4.p1.i @ 0x302675460>,
#  <OpticalNode IM4.p2.o @ 0x3026760c0>,
#  <OpticalNode PRMAR.p2.i @ 0x3034ac650>,
#  <OpticalNode PRMAR.p1.o @ 0x303966540>,
#  <OpticalNode PRM.p2.i @ 0x3034eabd0>,
#  <OpticalNode PRM.p1.o @ 0x3034eba70>,
#  <OpticalNode PR2.p1.i @ 0x3034afd70>,
#  <OpticalNode PR2.p2.o @ 0x3034ae570>,
#  <OpticalNode PR3.p1.i @ 0x3034aec00>,
#  <OpticalNode PR3.p2.o @ 0x3034ac8c0>,
#  <OpticalNode BS.p1.i @ 0x3033cbc80>,
# ...

# %%
ps = lho.path(lho.MC1.p2, lho.PRMAR.p1)

# %%
ps.nodes
# Out:
# [<OpticalNode MC1.p2.o @ 0x302659880>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>,
#  <OpticalNode MC3.p3.o @ 0x3040996d0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>,
#  <OpticalNode IM2.p2.o @ 0x302677530>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>,
#  <OpticalNode IM3.p1.i @ 0x302675580>,
#  <OpticalNode IM3.p2.o @ 0x302675a00>,
#  <OpticalNode IM4.p1.i @ 0x302675460>,
#  <OpticalNode IM4.p2.o @ 0x3026760c0>,
#  <OpticalNode PRMAR.p2.i @ 0x3034ac650>,
#  <OpticalNode PRMAR.p1.o @ 0x303966540>,
#  <OpticalNode PRM.p2.i @ 0x3034eabd0>,
#  <OpticalNode PRM.p2.o @ 0x17e881ca0>,
#  <OpticalNode PRMAR.p1.i @ 0x3034ac0b0>]

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.PRMAR.p1)

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps = lho.propagate_beam(lho.MC3.p1, lho.PRMAR.p1)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 ps = lho.propagate_beam(lho.MC3.p1, lho.PRMAR.p1)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
#    4332     **kwargs,
#    4333 )
#
# ...

# %%
ps = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p1)

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p2)

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps
# Out:
# <PropagationSolution of Propagation_MC3.p3.o_PRMAR.p2.i_x @ 0x3050f63c0 children=0>

# %%
ps.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303cab290>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303269250>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x30326b110>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x30326a810>,
#  <OpticalNode IM2.p2.o @ 0x302677530>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x303268ef0>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x303268e60>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x30326ab10>,
# ...

# %%
ps = lho.propagate_beam(lho.MC3.p3, lho.M5.p1)

# %%
p = lho.path(lho.MC3.p3, lho.M5.p1)

# %%
p

# %%
p.nodes
# Out:
# [<OpticalNode MC3.p3.o @ 0x3040996d0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>,
#  <OpticalNode IM2.p2.o @ 0x302677530>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>,
#  <OpticalNode IM3.p1.i @ 0x302675580>,
#  <OpticalNode IM3.p2.o @ 0x302675a00>,
#  <OpticalNode IM4.p1.i @ 0x302675460>,
#  <OpticalNode IM4.p2.o @ 0x3026760c0>,
#  <OpticalNode PRMAR.p2.i @ 0x3034ac650>,
#  <OpticalNode PRMAR.p2.o @ 0x3034ac740>,
#  <OpticalNode IM4.p2.i @ 0x3026753a0>,
#  <OpticalNode IM4.p1.o @ 0x302675220>,
#  <OpticalNode IM3.p2.i @ 0x302675d30>,
#  <OpticalNode IM3.p1.o @ 0x302675ac0>,
#  <OpticalNode IFI.p3.i @ 0x302674740>,
#  <OpticalNode IFI.p4.o @ 0x302676900>,
#  <OpticalNode IM2_REFL.p1.i @ 0x303025ca0>,
#  <OpticalNode IM2_REFL.p2.o @ 0x3034da090>,
#  <OpticalNode LossyMirror.p1.i @ 0x3026e4500>,
#  <OpticalNode LossyMirror.p3.o @ 0x3026e4950>,
# ...

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
lho.IM2
# Out:
# <'IM2' @ 0x301f44200 (Beamsplitter)>

# %%
lho.IM2.params
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 lho.IM2.params
#
# AttributeError: 'Beamsplitter' object has no attribute 'params'

# %%
lho.IM2.parameters
# Out:
# [<IM2.misaligned=False @ 0x303c4f880>,
#  <IM2.plane=0 @ 0x303c4f940>,
#  <IM2.ybeta=0.0 @ 0x303c4fa00>,
#  <IM2.xbeta=0.0 @ 0x303c4fac0>,
#  <IM2.Rcy=12.8 @ 0x303c4fb80>,
#  <IM2.Rcx=12.8 @ 0x303c4fc40>,
#  <IM2.alpha=7.0 @ 0x303c4fd00>,
#  <IM2.phi=0.0 @ 0x303c4fdc0>,
#  <IM2.L=0.0 @ 0x303c4fe80>,
#  <IM2.T=0.0 @ 0x303c4ff40>,
#  <IM2.R=1.0 @ 0x303adc040>]

# %%
ps.positions
# Out:
# {<'MC3' @ 0x30327c350 (Beamsplitter)>: 0.0,
#  <'IM1' @ 0x3026e40e0 (Beamsplitter)>: 0.4282,
#  <'IM2' @ 0x301f44200 (Beamsplitter)>: 1.722,
#  <'IFI' @ 0x302574530 (DirectionalBeamsplitter)>: 1.982,
#  <'IM3' @ 0x3037dc1a0 (Beamsplitter)>: 2.892,
#  <'IM4' @ 0x301eb8ef0 (Beamsplitter)>: 4.067,
#  <'PRMAR' @ 0x3034ac9e0 (Mirror)>: 4.48,
#  <'IM2_REFL' @ 0x30335c230 (Beamsplitter)>: 7.238,
#  <'LossyMirror' @ 0x303025e20 (Beamsplitter)>: 7.238,
#  <'RM1' @ 0x3026e7dd0 (Beamsplitter)>: 11.3975,
#  <'RM2' @ 0x3037dfe60 (Beamsplitter)>: 12.2355,
#  <'M5' @ 0x302574800 (Beamsplitter)>: 13.1455}

# %%
ps = lho.propagate_beam(lho.MC3.p3, lho.M5.p1, direction ='x')

# %%
ps.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303bed0a0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303cc6030>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303272c00>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3037e7e90>,
#  <OpticalNode IM2.p2.o @ 0x302677530>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x3037e4380>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x303e0dc10>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3039b89b0>,
# ...

# %%
ps = lho.propagate_beam(lho.MC3.p3, lho.M5.p1, direction ='y')

# %%
ps.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x301f52e40>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3032bc920>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303ca8a10>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>: <BeamParam (w0=2.1257 mm, w=2.1389 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x301f50b30>,
#  <OpticalNode IM2.p2.o @ 0x302677530>: <BeamParam (w0=963.01 um, w=2.1389 mm, z=-5.4303 m, nr=1, λ=1.064 um) at 0x303dac290>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x301f53ec0>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x301f522a0>,
# ...

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC
from finesse_ligo.factory import ALIGOFactory

from finesse.tracing.tree import TraceTree

finesse.init_plotting()

# %%
ps_s = lho.propagate_beam(lho.MC3.p3, lho.M5.p1, direction ='y')

# %%
ps_s.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d655b0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303dcfa40>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303d674d0>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>: <BeamParam (w0=2.1257 mm, w=2.1389 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x303d64e30>,
#  <OpticalNode IM2.p2.o @ 0x302677530>: <BeamParam (w0=963.01 um, w=2.1389 mm, z=-5.4303 m, nr=1, λ=1.064 um) at 0x303d666c0>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x303d64a40>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x303d66090>,
# ...

# %%
ps_t = lho.propagate_beam(lho.MC3.p3, lho.M5.p1, direction ='x')

# %%
ps_t.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x301f510a0>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x301f5daf0>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x301f5e780>,
#  <OpticalNode IM2.p1.i @ 0x302677f20>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x301f5d1f0>,
#  <OpticalNode IM2.p2.o @ 0x302677530>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x301f5c2c0>,
#  <OpticalNode IFI.p1.i @ 0x30254f200>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x301f5de80>,
#  <OpticalNode IFI.p3.o @ 0x302675d00>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x301f5f7d0>,
# ...

# %%
lho.IM2.parameters
# Out:
# [<IM2.misaligned=False @ 0x303c4f880>,
#  <IM2.plane=0 @ 0x303c4f940>,
#  <IM2.ybeta=0.0 @ 0x303c4fa00>,
#  <IM2.xbeta=0.0 @ 0x303c4fac0>,
#  <IM2.Rcy=12.8 @ 0x303c4fb80>,
#  <IM2.Rcx=12.8 @ 0x303c4fc40>,
#  <IM2.alpha=7.0 @ 0x303c4fd00>,
#  <IM2.phi=0.0 @ 0x303c4fdc0>,
#  <IM2.L=0.0 @ 0x303c4fe80>,
#  <IM2.T=0.0 @ 0x303c4ff40>,
#  <IM2.R=1.0 @ 0x303adc040>]

# %%
lho.IM1.parameters
# Out:
# [<IM1.misaligned=False @ 0x304024400>,
#  <IM1.plane=0 @ 0x304024340>,
#  <IM1.ybeta=0.0 @ 0x304024100>,
#  <IM1.xbeta=0.0 @ 0x304024040>,
#  <IM1.Rcy=inf @ 0x303f87880>,
#  <IM1.Rcx=inf @ 0x303f87a00>,
#  <IM1.alpha=53.0 @ 0x303f87940>,
#  <IM1.phi=0.0 @ 0x303f87040>,
#  <IM1.L=0.0 @ 0x303f871c0>,
#  <IM1.T=0.0 @ 0x303f87100>,
#  <IM1.R=1.0 @ 0x303f85c00>]

# %%
ps_t.abcd
# Out:
# <bound method PropagationSolution.abcd of <PropagationSolution of Propagation_MC3.p3.o_M5.p1.i_x @ 0x30692a2e0 children=0>>

# %%
ps_t.full_ABCD
# Out:
# array([[ -1.72026768, -12.21588354],
#        [ -2.1247176 , -15.66924903]])

# %%
ps_t = lho.propagate_beam(lho.MC3.p3, lho.IM3.p1, direction ='x')

# %%
ps_t.full_ABCD
# Out:
# array([[ 0.81581461,  2.57483276],
#        [-0.15742341,  0.72891689]])

# %%
ps_s = lho.propagate_beam(lho.MC3.p3, lho.IM3.p1, direction ='y')

# %%
ps_s.full_ABCD
# Out:
# array([[ 0.81855016,  2.57954337],
#        [-0.15508534,  0.73294305]])

# %%
ps_x = lho.propagate_beam(lho.MC1.p1, lho.MC3.p1, direction='x')
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 ps_x = lho.propagate_beam(lho.MC1.p1, lho.MC3.p1, direction='x')
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
#    4332     **kwargs,
#    4333 )
#
# ...

# %%
path = lho.path(lho.MC1, lho.MC3)
path.nodes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 path = lho.path(lho.MC1, lho.MC3)
#       2 path.nodes
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3625, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3591 def path(self, from_node, to_node, via_node=None, symbolic=False):
#    3592     """Retrieves an ordered container of the path trace between the specified nodes.
#    3593
#    3594     The return type is an :class:`.OpticalPath` instance which stores an underlying
#    (...)   3623         If no path can be found between `from_node` and `to_node`.
#    3624     """
# -> 3625     from_node, to_node, via_node = self.__parse_path_nodes(
#    3626         from_node, to_node, via_node
#    3627     )
#    3629     try:
#    3630         self.__node_exists_check(from_node)
#
# ...

# %%
path = lho.path(lho.MC1.p1, lho.MC3.p1)
path.nodes
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 path = lho.path(lho.MC1.p1, lho.MC3.p1)
#       2 path.nodes
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3643, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3641 if via_node is None:
#    3642     try:
# -> 3643         path = nx.shortest_path(self.optical_network, from_node, to_node)
#    3644     except nx.exception.NetworkXNoPath:
#    3645         raise
#
# File <class 'networkx.utils.decorators.argmap'> compilation 34:3, in argmap_shortest_path_31(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...

# %%
path = lho.path(lho.MC1.p1, lho.MC3.p2)
path.nodes
# Out:
# [<OpticalNode MC1.p1.o @ 0x30347e540>, <OpticalNode MC3.p2.i @ 0x3040996a0>]

# %%
path = lho.path(lho.MC1.p2, lho.MC3.p2)
path.nodes
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 path = lho.path(lho.MC1.p2, lho.MC3.p2)
#       2 path.nodes
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3643, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3641 if via_node is None:
#    3642     try:
# -> 3643         path = nx.shortest_path(self.optical_network, from_node, to_node)
#    3644     except nx.exception.NetworkXNoPath:
#    3645         raise
#
# File <class 'networkx.utils.decorators.argmap'> compilation 34:3, in argmap_shortest_path_31(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...

# %%
path = lho.path(lho.MC1.p2, lho.MC3.p1)
path.nodes
# Out:
# [<OpticalNode MC1.p2.o @ 0x302659880>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>]

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1)

# %%
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
ps.full_ABCD
# Out:
# array([[  0.19099786, -13.13865581],
#        [  0.07333473,   0.19099786]])

# %%
ps.symbolic
# Out:
# False

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, symbolic=True)

# %%
ps.full_ABCD
# Out:
# array([[<Symbolic='-((-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcx*cos(radians(MC2.alpha)))))*(MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr)-1.0)' @ 0x301e66f60>,
#         <Symbolic='((MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr)-((-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcx*cos(radians(MC2.alpha)))))*(MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr)-1.0)*(MC1_p2__MC2_p1.L/MC1_p2__MC2_p1.nr))' @ 0x301e65730>],
#        [<Symbolic='-(-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcx*cos(radians(MC2.alpha)))))' @ 0x303c72900>,
#         <Symbolic='(-(-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcx*cos(radians(MC2.alpha)))))*(MC1_p2__MC2_p1.L/MC1_p2__MC2_p1.nr)+1.0)' @ 0x301e66210>]],
#       dtype=object)

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, symbolic=True, direction='y')

# %%
ps.full_ABCD
# Out:
# array([[<Symbolic='-((MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr)*((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcy/cos(radians(MC2.alpha))))+1.0)' @ 0x3042a5370>,
#         <Symbolic='(-((MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr)*((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcy/cos(radians(MC2.alpha))))+1.0)*(MC1_p2__MC2_p1.L/MC1_p2__MC2_p1.nr)-(MC2_p2__MC3_p1.L/MC2_p2__MC3_p1.nr))' @ 0x3042a5100>],
#        [<Symbolic='-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcy/cos(radians(MC2.alpha))))' @ 0x3042a7e60>,
#         <Symbolic='(-((-2*MC1_p2__MC2_p1.nr)/(MC2.Rcy/cos(radians(MC2.alpha))))*(MC1_p2__MC2_p1.L/MC1_p2__MC2_p1.nr)-1.0)' @ 0x3042a7170>]],
#       dtype=object)

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1)

# %%
ps.qs
# Out:
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x30261dfa0>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303cf5cd0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x303cf5d60>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303cf7740>}

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction = 'y')

# %%
ps.qs
# Out:
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x303d73950>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303d64440>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x303d66e70>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d649e0>}

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, symbolic=True, direction='y')

# %%
ps.qs
# Out:
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x301e64710>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303d72ed0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x303ccacf0>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d72b10>}

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, symbolic=True, direction='y')

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='y')

# %%
ps.full_ABCD
# Out:
# array([[-0.19075394, 13.14261736],
#        [-0.07331971, -0.19075394]])

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='x')

# %%
ps.full_ABCD
# Out:
# array([[  0.19099786, -13.13865581],
#        [  0.07333473,   0.19099786]])

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='y')

# %%
ps.full_ABCD
# Out:
# array([[-0.19075394, 13.14261736],
#        [-0.07331971, -0.19075394]])

# %%
ps = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='y')

# %%
psx = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='x')
psx.full_ABCD
psx.qs
# Out:
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x301e67020>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303e6e150>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x30261dbe0>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x30261f3b0>}

# %%
psx = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='x')
print(psx.full_ABCD)
print(psx.qs)
# Out:
# [[  0.19099786 -13.13865581]
#  [  0.07333473   0.19099786]]
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x303d7c920>, <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303ca2090>, <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x303e7f9b0>, <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303e7d340>}

# %%
psy = lho.propagate_beam(lho.MC1.p2, lho.MC3.p1, direction='y')
print(psy.full_ABCD)
print(psy.qs)
# Out:
# [[-0.19075394 13.14261736]
#  [-0.07331971 -0.19075394]]
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x3042a4ec0>, <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303c71250>, <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x303d7ec90>, <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d7f7a0>}

# %%
psy = lho.propagate_beam(lho.MC1.p2, lho.IM3.p1, direction='y')
print(psy.full_ABCD)
print(psy.qs)
# Out:
# [[-0.34527304 10.26583345]
#  [-0.02415604 -2.178039  ]]
# ...

# %%
psy = lho.propagate_beam(lho.MC1.p2, lho.IM3.p1, direction='y')
print(psy.full_ABCD)
psy.qs
# Out:
# [[-0.34527304 10.26583345]
#  [-0.02415604 -2.178039  ]]
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x3042a5970>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x3033cbdd0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x3033caf60>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3033cacf0>,
#  <OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3033c8680>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303d7c8f0>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303d7df70>,
# ...

# %%
psy = lho.propagate_beam(lho.MC1.p2, lho.IM3.p2, direction='y')
print(psy.full_ABCD)
psy.qs
# Out:
# [[-0.77076777 13.71834162]
#  [-0.13397189  1.08706177]]
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x303dbc710>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x3042a66c0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1257 mm, w=3.3775 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x3042a4860>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3042a72c0>,
#  <OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3042a7380>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3042a7bc0>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3042a6c90>,
# ...

# %%
psx = lho.propagate_beam(lho.MC1.p2, lho.IM3.p2, direction='x')
print(psx.full_ABCD)
psx.qs
# Out:
# [[  0.77246227 -13.70665463]
#  [  0.13470364  -1.09563439]]
# {<OpticalNode MC1.p2.o @ 0x302659880>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x303db4fb0>,
#  <OpticalNode MC2.p1.i @ 0x3032b38f0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x303cf63f0>,
#  <OpticalNode MC2.p2.o @ 0x3032b3710>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x3041157c0>,
#  <OpticalNode MC3.p1.i @ 0x30409aed0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d7dcd0>,
#  <OpticalNode MC3.p3.o @ 0x3040996d0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x303d7eb10>,
#  <OpticalNode IM1.p1.i @ 0x3032b4710>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303d7c1a0>,
#  <OpticalNode IM1.p2.o @ 0x303dfbda0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x303d7dfa0>,
# ...

# %% [markdown]
# Connected to finesseligo (Python 3.12.8)

# %%
# beam propagation cross check
import matplotlib.pyplot as plt
import finesse
import finesse.components as fc
import finesse.detectors as fd
import finesse_ligo
import numpy as np
from finesse.analysis.actions import For, Series, Execute, RunLocks, Noxaxis, SensingMatrixDC
from finesse_ligo.factory import ALIGOFactory

from finesse.tracing.tree import TraceTree

finesse.init_plotting()

# %%
factory = ALIGOFactory("lho_O4.yaml")

factory.options.INPUT.add_IMC_and_IM1 = True

lho = factory.make()
lho.fsig.f = 1

# %%
# beam propagation from IMC to PRMAR
path = lho.path(lho.MC3.p3, lho.PRMAR.p2)
path.nodes
ps = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p2)
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
# beam propagation from IMC to REFL port at M5

path = lho.path(lho.MC3.p3, lho.M5.p1)
path.nodes
ps = lho.propagate_beam(lho.MC3.p3, lho.M5.p1)
ps.plot()
# Out:
# (<Figure size 576x355.968 with 2 Axes>,
#  array([<Axes: ylabel='Beam size [mm]'>,
#         <Axes: xlabel='Distance [m]', ylabel='Gouy phase\naccumulation [deg]'>],
#        dtype=object))

# %%
model.cavIMC.ABCDx
model.cavIMC.ABCDy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.cavIMC.ABCDx
#       2 model.cavIMC.ABCDy
#
# NameError: name 'model' is not defined

# %%
lho.cavIMC.ABCDx
lho.cavIMC.ABCDy
# Out:
# array([[-0.2248476 , 13.05391678],
#        [-0.07331971, -0.19075394]])

# %%
lho.cavIMC.ABCDx
# Out:
# array([[  0.22509852, -13.0498418 ],
#        [  0.07333473,   0.19099786]])

# %%
lho.cavIMC.ABCDy
# Out:
# array([[-0.2248476 , 13.05391678],
#        [-0.07331971, -0.19075394]])

# %%
lho.cavIMC.qx
# Out:
# <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x3041928a0>

# %%
lho.cavIMC.qy
# Out:
# <BeamParam (w0=2.1257 mm, w=2.126 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x304907800>

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.IM3.p2, direction='x')
print(psx.full_ABCD)
psx.qs
# Out:
# [[1.1527125  7.53117416]
#  [0.10607616 1.5605609 ]]
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c948f0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304c53f50>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304c53fb0>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x304c53e90>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x304c53ef0>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x304c53dd0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x304c53e30>,
# ...

# %%
psy = lho.propagate_beam(lho.MC3.p3, lho.IM3.p2, direction='y')
print(psy.full_ABCD)
psy.qs
# Out:
# [[1.15285186 7.51307824]
#  [0.10525872 1.55338   ]]
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c95670>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x30403e000>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304abc2c0>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1257 mm, w=2.1389 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x304abc110>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=963.01 um, w=2.1389 mm, z=-5.4303 m, nr=1, λ=1.064 um) at 0x304abfc20>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x304abde20>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x304abf800>,
# ...

# %%
# beam propagation from IMC to PRMAR
path = lho.path(lho.MC3.p3, lho.PRMAR.p2)
path.nodes
psx = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p2, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304a65fa0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304a42d80>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304a42870>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x304a42e40>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x304a40560>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x30497cb90>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x30497c1a0>,
# ...

# %%
psy = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p2, direction='y')
psy.plot()
psy.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1257 mm, w=2.126 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304d47350>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304c9a720>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1257 mm, w=2.1259 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304d47320>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1257 mm, w=2.1389 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x304d47f80>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=963.01 um, w=2.1389 mm, z=-5.4303 m, nr=1, λ=1.064 um) at 0x304d47fe0>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x304d47ec0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=963.01 um, w=2.0576 mm, z=-5.1703 m, nr=1, λ=1.064 um) at 0x304d47f20>,
# ...

# %%
0.260 + 0.91
# Out:
# 1.17

# %%
path = lho.path(lho.MC3.p3, lho.M5.p1)

# %%
path.nodes
# Out:
# [<OpticalNode MC3.p3.o @ 0x3040d0fb0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>,
#  <OpticalNode IM3.p1.i @ 0x303f4e180>,
#  <OpticalNode IM3.p2.o @ 0x303f4e300>,
#  <OpticalNode IM4.p1.i @ 0x303f4e9f0>,
#  <OpticalNode IM4.p2.o @ 0x303f4eb70>,
#  <OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p2.o @ 0x303e1fa10>,
#  <OpticalNode IM4.p2.i @ 0x303f4eb10>,
#  <OpticalNode IM4.p1.o @ 0x303f4ea50>,
#  <OpticalNode IM3.p2.i @ 0x303f4e2a0>,
#  <OpticalNode IM3.p1.o @ 0x303f4e1e0>,
#  <OpticalNode IFI.p3.i @ 0x303f4d820>,
#  <OpticalNode IFI.p4.o @ 0x303f4d9a0>,
#  <OpticalNode IM2_REFL.p1.i @ 0x303f9acc0>,
#  <OpticalNode IM2_REFL.p2.o @ 0x303e6b890>,
#  <OpticalNode LossyMirror.p1.i @ 0x303db2c30>,
#  <OpticalNode LossyMirror.p3.o @ 0x303fcca70>,
# ...

# %%
path = lho.path(lho.PRMAR.p2, lho.PR2.p1)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 path = lho.path(lho.PRMAR.p2, lho.PR2.p1)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:3643, in Model.path(self, from_node, to_node, via_node, symbolic)
#    3641 if via_node is None:
#    3642     try:
# -> 3643         path = nx.shortest_path(self.optical_network, from_node, to_node)
#    3644     except nx.exception.NetworkXNoPath:
#    3645         raise
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:3, in argmap_shortest_path_1(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...

# %%
path = lho.path(lho.PRMAR.p1, lho.PR2.p1)

# %%
path.nodes
# Out:
# [<OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p1.o @ 0x303b839e0>,
#  <OpticalNode PR2.p1.i @ 0x303e1fe60>]

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PRMAR.p1, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304d5c8f0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304d53440>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304d4af30>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3046eb440>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x3049046e0>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x304906720>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3049043e0>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.IM2_REFL.p1, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x305c0f7d0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304d574a0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x304d57ef0>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x304d57ad0>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x304d57200>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305b79310>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305b79370>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p1, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x305cb7f20>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305cb7f80>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305cb7fe0>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x305cb7e90>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x305cb7ef0>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305cb7dd0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305cb7e30>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p2, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x306ad1160>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305ca3020>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x306ac7f20>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x306ac7f80>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x306ac7e60>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x306ac7ec0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x306ac7da0>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p3, direction='x')
psx.plot()
psx.qs
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p3, direction='x')
#       2 psx.plot()
#       3 psx.qs
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p1, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3180c0260>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305cab440>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3180aaf00>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3180aa4e0>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x3180aa300>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3180a9700>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3180a9790>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PRM.p1, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3181c8590>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x306a670b0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305bfade0>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3180a96a0>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x305cae570>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305cafd10>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x318145490>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PRM.p1.o, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x318318fb0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3182f3680>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3182f3920>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3182f29f0>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x3182f37d0>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3182f2690>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3182f2bd0>,
# ...

# %%
path = lho.path(lho.MC3.p3, lho.PR2.p1.o)

# %%
path.nodes
# Out:
# [<OpticalNode MC3.p3.o @ 0x3040d0fb0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>,
#  <OpticalNode IM3.p1.i @ 0x303f4e180>,
#  <OpticalNode IM3.p2.o @ 0x303f4e300>,
#  <OpticalNode IM4.p1.i @ 0x303f4e9f0>,
#  <OpticalNode IM4.p2.o @ 0x303f4eb70>,
#  <OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p1.o @ 0x303b839e0>,
#  <OpticalNode PR2.p1.i @ 0x303e1fe60>,
#  <OpticalNode PR2.p2.o @ 0x303e1ffe0>,
#  <OpticalNode PR3.p1.i @ 0x303e306b0>,
#  <OpticalNode PR3.p2.o @ 0x303e30830>,
#  <OpticalNode BS.p1.i @ 0x303b8c4a0>,
#  <OpticalNode BS.p2.o @ 0x303b8c9e0>,
#  <OpticalNode ITMYlens.p1.i @ 0x303de3e60>,
#  <OpticalNode ITMYlens.p2.o @ 0x303b70bf0>,
#  <OpticalNode CPY1.p1.i @ 0x303df9190>,
# ...

# %%
path = lho.path(lho.MC3.p3, lho.PR2.p2.o)

# %%
path.nodes
# Out:
# [<OpticalNode MC3.p3.o @ 0x3040d0fb0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>,
#  <OpticalNode IM3.p1.i @ 0x303f4e180>,
#  <OpticalNode IM3.p2.o @ 0x303f4e300>,
#  <OpticalNode IM4.p1.i @ 0x303f4e9f0>,
#  <OpticalNode IM4.p2.o @ 0x303f4eb70>,
#  <OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p1.o @ 0x303b839e0>,
#  <OpticalNode PR2.p1.i @ 0x303e1fe60>,
#  <OpticalNode PR2.p2.o @ 0x303e1ffe0>]

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p2.o, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3180ab470>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3180ab590>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3180ab740>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x3180ab830>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x3180ab770>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3180ab5c0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x3180ab290>,
# ...

# %%
ps.optical_path_length
# Out:
# 13.1455

# %%
ps.path_length
# Out:
# 13.1455

# %%
psx.path_length
# Out:
# 21.1636

# %%
psx.optical_path_length
# Out:
# 21.19735

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.PR2.p2.o, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x305cae2a0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3040886e0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x305dc0680>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x305dc1d90>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x305dc1c10>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305dc1dc0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x305dc00e0>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via=PRM.p2.i, direction='x')
psx.plot()
psx.qs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via=PRM.p2.i, direction='x')
#       2 psx.plot()
#       3 psx.qs
#
# NameError: name 'PRM' is not defined

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via=lho.PRM.p2.i, direction='x')
psx.plot()
psx.qs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via=lho.PRM.p2.i, direction='x')
#       2 psx.plot()
#       3 psx.qs
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, vi_node=lho.PRM.p2.i, direction='x')
psx.plot()
psx.qs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, vi_node=lho.PRM.p2.i, direction='x')
#       2 psx.plot()
#       3 psx.qs
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via_node=lho.PRM.p2.i, direction='x')
psx.plot()
psx.qs
# Out:
# {<OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x305c09610>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3180f08c0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>: <BeamParam (w0=2.1254 mm, w=2.1256 mm, z=195.7 mm, nr=1, λ=1.064 um) at 0x3180f3440>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>: <BeamParam (w0=2.1254 mm, w=2.1386 mm, z=1.4895 m, nr=1, λ=1.064 um) at 0x307b6b920>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>: <BeamParam (w0=951.01 um, w=2.1386 mm, z=-5.3787 m, nr=1, λ=1.064 um) at 0x307b69a90>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x307b6b650>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>: <BeamParam (w0=951.01 um, w=2.0561 mm, z=-5.1187 m, nr=1, λ=1.064 um) at 0x307b6a660>,
# ...

# %%
psx.components
# Out:
# [<'MC3' @ 0x3040d03e0 (Beamsplitter)>,
#  <'IM1' @ 0x30411b7a0 (Beamsplitter)>,
#  <'IM2' @ 0x303f00560 (Beamsplitter)>,
#  <'IFI' @ 0x303ebc620 (DirectionalBeamsplitter)>,
#  <'IM3' @ 0x303f43bc0 (Beamsplitter)>,
#  <'IM4' @ 0x303ed3bf0 (Beamsplitter)>,
#  <'PRMAR' @ 0x303e1f800 (Mirror)>,
#  <'PRM' @ 0x303b83b60 (Mirror)>,
#  <'IM2_REFL' @ 0x303fb99a0 (Beamsplitter)>,
#  <'LossyMirror' @ 0x303fb8350 (Beamsplitter)>,
#  <'RM1' @ 0x303fb2390 (Beamsplitter)>]

# %%
psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via_node=lho.PRM.p2.i, direction='x', symbolic=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p3, lho.RM1.p1, via_node=lho.PRM.p2.i, direction='x', symbolic=True)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
# ...

# %%
psx = lho.propagate_beam(lho.IM3.p2, lho.IM2_REFL.p1, via_node=lho.PRM.p2.i, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[<Symbolic='-(((((((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr)-(((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr))*(-((-2*IM3_p2__IM4_p1.nr)/(IM3.Rcx*cos(radians(IM3.alpha)))))+((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr)-(((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr))*(-((-2*IM3_p2__IM4_p1.nr)/(IM3.Rcx*cos(radians(IM3.alpha)))))-1.0)*(IM3_p2__IM4_p1.L/IM3_p2__IM4_p1.nr))*(-((-2*IM4_p2__PRMAR_p2.nr)/(IM4.Rcx*cos(radians(IM4.alpha)))))-1.0)*(IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)-(((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr))*(-((-2*IM3_p2__IM4_p1.nr)/(IM3.Rcx*cos(radians(IM3.alpha)))))-1.0)*(IM3_p2__IM4_p1.L/IM3_p2__IM4_p1.nr))*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)-(((IFI_p3__IM3_p1.L/IFI_p3__IM3_p1.nr)+(IFI_p4__IM2_REFL_p1.L/IFI_p4__IM2_REFL_p1.nr))*(-((-2*IM3_p2__IM4_p1.nr)/(IM
# ...

# %%
psx = lho.propagate_beam(lho.PRMAR.p2, lho.IM4.p2, via_node=lho.PRM.p2.i, direction='x', symbolic=True)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 psx = lho.propagate_beam(lho.PRMAR.p2, lho.IM4.p2, via_node=lho.PRM.p2.i, direction='x', symbolic=True)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
# ...

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.IM4.p2, via_node=lho.PRM.p2.i, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[<Symbolic='((((IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)+1.0)*(subPRM.L/subPRM.nr)+(IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)-((((IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)+1.0)*(subPRM.L/subPRM.nr)+(IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr))*(-((-2*subPRM.nr)/-PRM.Rcx))-1.0*((IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)+1.0))*(subPRM.L/subPRM.nr))*((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)-((((IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)+1.0)*(subPRM.L/subPRM.nr)+(IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr))*(-((-2*subPRM.nr)/-PRM.Rcx))-1.0*((IM4_p2__PRMAR_p2.L/IM4_p2__PRMAR_p2.nr)*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)+1.0)))' @ 0x3182d3500>,
# ...

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRMAR.p2.o, via_node=lho.PRM.p2.i, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[<Symbolic='(((subPRM.L/subPRM.nr)-((-((-2*subPRM.nr)/-PRM.Rcx))*(subPRM.L/subPRM.nr)-1.0)*(subPRM.L/subPRM.nr))*((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)-((-((-2*subPRM.nr)/-PRM.Rcx))*(subPRM.L/subPRM.nr)-1.0))' @ 0x305cb0650>,
#         <Symbolic='((subPRM.L/subPRM.nr)-((-((-2*subPRM.nr)/-PRM.Rcx))*(subPRM.L/subPRM.nr)-1.0)*(subPRM.L/subPRM.nr))' @ 0x305cb0aa0>],
#        [<Symbolic='((((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)*(subPRM.L/subPRM.nr)-((((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)*(subPRM.L/subPRM.nr)+1.0)*(-((-2*subPRM.nr)/-PRM.Rcx))-1.0*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx))*(subPRM.L/subPRM.nr)+1.0)*((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)-((((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)*(subPRM.L/subPRM.nr)+1.0)*(-((-2*subPRM.nr)/-PRM.Rcx))-1.0*((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)))' @ 0x305cb0c80>,
# ...

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRMAR.p2.o, via_node=lho.PRM.p2.i, direction='x')

# %%
psx.full_ABCD
# Out:
# array([[-0.98629887, -0.1027396 ],
#        [ 0.26488856, -0.98629887]])

# %%
psx.nodes
# Out:
# [<OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p2.o @ 0x303e1f230>,
#  <OpticalNode PRMAR.p1.i @ 0x303e1f830>,
#  <OpticalNode PRMAR.p2.o @ 0x303e1fa10>]

# %%
psx.ports
# Out:
# [<Port PRMAR.p2 Type=NodeType.OPTICAL @ 0x303e1f980>,
#  <Port PRMAR.p1 Type=NodeType.OPTICAL @ 0x303bb41a0>,
#  <Port PRM.p2 Type=NodeType.OPTICAL @ 0x303e1de80>]

# %%
lho.subPRM.L
# Out:
# <subPRM.L=0.075 @ 0x303e0f400>

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRMAR.p1.o, direction='x')

# %%
psx.nodes
# Out:
# [<OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>]

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRMAR.p1.o, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[1.0, 0.0],
#        [<Symbolic='((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)' @ 0x303bb7a10>,
#         1.0]], dtype=object)

# %%
psx = lho.propagate_beam(lho.PRMAR.p1.o, lho.PRM.p2.i, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[1.0, <Symbolic='(subPRM.L/subPRM.nr)' @ 0x3047c5b80>],
#        [0.0, 1.0]], dtype=object)

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRM.p2.o, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[<Symbolic='((subPRM.L/subPRM.nr)*((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)+1.0)' @ 0x3181ca930>,
#         <Symbolic='(subPRM.L/subPRM.nr)' @ 0x3047c5b80>],
#        [<Symbolic='((-(-((-2*subPRM.nr)/-PRM.Rcx))*(subPRM.L/subPRM.nr)+1.0)*((subPRM.nr-IM4_p2__PRMAR_p2.nr)/-PRMAR.Rcx)-(-((-2*subPRM.nr)/-PRM.Rcx)))' @ 0x305c0d910>,
#         <Symbolic='(-(-((-2*subPRM.nr)/-PRM.Rcx))*(subPRM.L/subPRM.nr)+1.0)' @ 0x3181cbef0>]],
#       dtype=object)

# %%
psx.nodes
# Out:
# [<OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p2.o @ 0x303e1f230>]

# %%
psx = lho.propagate_beam(lho.PRM.p2.i, lho.PRM.p2.o, direction='x', symbolic=True)

# %%
psx.nodes
# Out:
# [<OpticalNode PRM.p2.i @ 0x303e1e720>, <OpticalNode PRM.p2.o @ 0x303e1f230>]

# %%
psx.full_ABCD
# Out:
# array([[1.0, 0.0],
#        [<Symbolic='-(-((-2*subPRM.nr)/-PRM.Rcx))' @ 0x307b42b40>, 1.0]],
#       dtype=object)

# %%
psx = lho.propagate_beam(lho.PRM.p2.i, lho.PRM.p2.o, direction='x')

# %%
psx.full_ABCD
# Out:
# array([[-1.        , -0.        ],
#        [ 0.26488856, -1.        ]])

# %%
psx.nodes
# Out:
# [<OpticalNode PRM.p2.i @ 0x303e1e720>, <OpticalNode PRM.p2.o @ 0x303e1f230>]

# %%
psx.ports
# Out:
# [<Port PRM.p2 Type=NodeType.OPTICAL @ 0x303e1de80>]

# %%
lho.PRM
# Out:
# <'PRM' @ 0x303b83b60 (Mirror)>

# %%
lho.PRM.parameters
# Out:
# [<PRM.misaligned=False @ 0x303e0cac0>,
#  <PRM.ybeta=0.0 @ 0x303e0cb80>,
#  <PRM.xbeta=0.0 @ 0x303e0cc40>,
#  <PRM.Rcy=-10.948 @ 0x303e0cd00>,
#  <PRM.Rcx=-10.948 @ 0x303e0cdc0>,
#  <PRM.phi=(PRCL.DC+(-1.0*MICH2.DC)) @ 0x303e0ce80>,
#  <PRM.L=0.0 @ 0x303e0cf40>,
#  <PRM.T=0.031 @ 0x303e0d000>,
#  <PRM.R=0.969 @ 0x303e0d0c0>]

# %%
psx = lho.propagate_beam(lho.PRM.p2.o, lho.PRMAR.p1.i, direction='x')

# %%
psx.full_ABCD
# Out:
# array([[1.        , 0.05172414],
#        [0.        , 1.        ]])

# %%
psx = lho.propagate_beam(lho.PRMAR.p1.i, lho.PRMAR.p2.o, direction='x')

# %%
psx.full_ABCD
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
psx = lho.propagate_beam(lho.PRMAR.p1.i, lho.PRMAR.p2.o, direction='x', symbolic=True)

# %%
psx.full_ABCD
# Out:
# array([[1.0, 0.0],
#        [<Symbolic='((IM4_p2__PRMAR_p2.nr-subPRM.nr)/PRMAR.Rcx)' @ 0x303bb42c0>,
#         1.0]], dtype=object)

# %%
psx = lho.propagate_beam(lho.PRM.p2.i, lho.PRM.p2.o, direction='x')

# %%
psx.full_ABCD
# Out:
# array([[-1.        , -0.        ],
#        [ 0.26488856, -1.        ]])

# %%
psx = lho.propagate_beam(lho.PRMAR.p2.i, lho.PRMAR.p1.o, direction='x', symbolic=False)

# %%
psx.full_ABCD
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
psx = lho.propagate_beam(lho.PRMAR.p1.o, lho.PRM.p2.i, direction='x', symbolic=False)

# %%
psx.full_ABCD
# Out:
# array([[1.        , 0.05172414],
#        [0.        , 1.        ]])

# %%
psy = lho.propagate_beam(lho.PRM.p2.i, lho.PRM.p2.o, direction='y')

# %%
psy.full_ABCD
# Out:
# array([[ 1.        ,  0.        ],
#        [-0.26488856,  1.        ]])

# %%
psx = lho.propagate_beam(lho.MC3.p2, lho.IM3.p1, direction='x', via_node = lho.PRM.p2.i, symbolic=False)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 psx = lho.propagate_beam(lho.MC3.p2, lho.IM3.p1, direction='x', via_node = lho.PRM.p2.i, symbolic=False)
#
# File ~/miniforge3/envs/finesseligo/lib/python3.12/site-packages/finesse/model.py:4322, in Model.propagate_beam(self, from_node, to_node, via_node, path, q_in, direction, symbolic, simplify, solution_name, **kwargs)
#    4314 """See :func:`finesse.tracing.tools.propagate_beam`
#    4315
#    4316 .. note::
#    (...)   4319     `via_node` can be specified as strings.
#    4320 """
#    4321 fn, tn, vn = self.__parse_path_nodes(from_node, to_node, via_node)
# -> 4322 return tracetools.propagate_beam(
#    4323     fn,
#    4324     tn,
#    4325     vn,
#    4326     path,
#    4327     q_in,
#    4328     direction,
#    4329     symbolic,
#    4330     simplify,
#    4331     solution_name,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p2, lho.IM3.p1.o, direction='x', via_node = lho.PRM.p2.i, symbolic=False)

# %%
psx.nodes
# Out:
# [<OpticalNode MC3.p2.o @ 0x3040d0980>,
#  <OpticalNode MC1.p1.i @ 0x304092cc0>,
#  <OpticalNode MC1.p2.o @ 0x3040a5df0>,
#  <OpticalNode MC2.p1.i @ 0x3040b6de0>,
#  <OpticalNode MC2.p2.o @ 0x3040b6f90>,
#  <OpticalNode MC3.p1.i @ 0x3040d0bf0>,
#  <OpticalNode MC3.p3.o @ 0x3040d0fb0>,
#  <OpticalNode IM1.p1.i @ 0x3040fc7a0>,
#  <OpticalNode IM1.p2.o @ 0x304123140>,
#  <OpticalNode IM2.p1.i @ 0x303f4da00>,
#  <OpticalNode IM2.p2.o @ 0x303f4db80>,
#  <OpticalNode IFI.p1.i @ 0x303f426c0>,
#  <OpticalNode IFI.p3.o @ 0x303f4d880>,
#  <OpticalNode IM3.p1.i @ 0x303f4e180>,
#  <OpticalNode IM3.p2.o @ 0x303f4e300>,
#  <OpticalNode IM4.p1.i @ 0x303f4e9f0>,
#  <OpticalNode IM4.p2.o @ 0x303f4eb70>,
#  <OpticalNode PRMAR.p2.i @ 0x303e1f9b0>,
#  <OpticalNode PRMAR.p1.o @ 0x303e1f920>,
#  <OpticalNode PRM.p2.i @ 0x303e1e720>,
#  <OpticalNode PRM.p2.o @ 0x303e1f230>,
#  <OpticalNode PRMAR.p1.i @ 0x303e1f830>,
#  <OpticalNode PRMAR.p2.o @ 0x303e1fa10>,
#  <OpticalNode IM4.p2.i @ 0x303f4eb10>,
# ...

# %%
psx.qs
# Out:
# {<OpticalNode MC3.p2.o @ 0x3040d0980>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3182f2750>,
#  <OpticalNode MC1.p1.i @ 0x304092cc0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x304c4b3e0>,
#  <OpticalNode MC1.p2.o @ 0x3040a5df0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x304c498e0>,
#  <OpticalNode MC2.p1.i @ 0x3040b6de0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x304c49a60>,
#  <OpticalNode MC2.p2.o @ 0x3040b6f90>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x304c4afc0>,
#  <OpticalNode MC3.p1.i @ 0x3040d0bf0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c4b020>,
#  <OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c4a930>,
# ...

# %%
psx = lho.propagate_beam(lho.MC3.p2, lho.RM1.p1, direction='x', via_node = lho.PRM.p2.i, symbolic=False)

# %%
psx.qs
# Out:
# {<OpticalNode MC3.p2.o @ 0x3040d0980>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3183b5400>,
#  <OpticalNode MC1.p1.i @ 0x304092cc0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x305bfdfa0>,
#  <OpticalNode MC1.p2.o @ 0x3040a5df0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x305bffb00>,
#  <OpticalNode MC2.p1.i @ 0x3040b6de0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x305bffd70>,
#  <OpticalNode MC2.p2.o @ 0x3040b6f90>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x3182f0650>,
#  <OpticalNode MC3.p1.i @ 0x3040d0bf0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3182f0da0>,
#  <OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x3182f2570>,
# ...

# %%
psx.positions
# Out:
# {<'MC3' @ 0x3040d03e0 (Beamsplitter)>: 0.0,
#  <'MC1' @ 0x304092d80 (Beamsplitter)>: 0.465,
#  <'MC2' @ 0x3040a4b00 (Beamsplitter)>: 16.70557,
#  <'IM1' @ 0x30411b7a0 (Beamsplitter)>: 33.37434,
#  <'IM2' @ 0x303f00560 (Beamsplitter)>: 34.668139999999994,
#  <'IFI' @ 0x303ebc620 (DirectionalBeamsplitter)>: 34.92813999999999,
#  <'IM3' @ 0x303f43bc0 (Beamsplitter)>: 35.83813999999999,
#  <'IM4' @ 0x303ed3bf0 (Beamsplitter)>: 37.013139999999986,
#  <'PRMAR' @ 0x303e1f800 (Mirror)>: 37.42613999999998,
#  <'PRM' @ 0x303b83b60 (Mirror)>: 37.501139999999985,
#  <'IM2_REFL' @ 0x303fb99a0 (Beamsplitter)>: 40.33413999999998,
#  <'LossyMirror' @ 0x303fb8350 (Beamsplitter)>: 40.33413999999998,
#  <'RM1' @ 0x303fb2390 (Beamsplitter)>: 44.49363999999998}

# %%
lho.IM2_REFL.AOI
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 lho.IM2_REFL.AOI
#
# AttributeError: 'Beamsplitter' object has no attribute 'AOI'

# %%
lho.IM2_REFL.parameters
# Out:
# [<IM2_REFL.misaligned=False @ 0x303f7d180>,
#  <IM2_REFL.plane=0 @ 0x303f7d240>,
#  <IM2_REFL.ybeta=0.0 @ 0x303f7d300>,
#  <IM2_REFL.xbeta=0.0 @ 0x303f7d3c0>,
#  <IM2_REFL.Rcy=12.8 @ 0x303f7d480>,
#  <IM2_REFL.Rcx=12.8 @ 0x303f7d540>,
#  <IM2_REFL.alpha=0.0 @ 0x303f7d600>,
#  <IM2_REFL.phi=0.0 @ 0x303f7d6c0>,
#  <IM2_REFL.L=0.0 @ 0x303f7d780>,
#  <IM2_REFL.T=0.0 @ 0x303f7d840>,
#  <IM2_REFL.R=1.0 @ 0x303f7d900>]

# %%
lho.IM2_REFL.alpha
# Out:
# <IM2_REFL.alpha=0.0 @ 0x303f7d600>

# %%
lho.IM2_REFL.alpha = 7.0

# %%
lho.IM2_REFL.parameters
# Out:
# [<IM2_REFL.misaligned=False @ 0x303f7d180>,
#  <IM2_REFL.plane=0 @ 0x303f7d240>,
#  <IM2_REFL.ybeta=0.0 @ 0x303f7d300>,
#  <IM2_REFL.xbeta=0.0 @ 0x303f7d3c0>,
#  <IM2_REFL.Rcy=12.8 @ 0x303f7d480>,
#  <IM2_REFL.Rcx=12.8 @ 0x303f7d540>,
#  <IM2_REFL.alpha=7.0 @ 0x303f7d600>,
#  <IM2_REFL.phi=0.0 @ 0x303f7d6c0>,
#  <IM2_REFL.L=0.0 @ 0x303f7d780>,
#  <IM2_REFL.T=0.0 @ 0x303f7d840>,
#  <IM2_REFL.R=1.0 @ 0x303f7d900>]

# %%
psx = lho.propagate_beam(lho.MC3.p2, lho.RM1.p1, direction='x', via_node = lho.PRM.p2.i, symbolic=False)

# %%
psx.qs
# Out:
# {<OpticalNode MC3.p2.o @ 0x3040d0980>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x305ca3bf0>,
#  <OpticalNode MC1.p1.i @ 0x304092cc0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x304c99d30>,
#  <OpticalNode MC1.p2.o @ 0x3040a5df0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=232.5 mm, nr=1, λ=1.064 um) at 0x304c9acc0>,
#  <OpticalNode MC2.p1.i @ 0x3040b6de0>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=16.473 m, nr=1, λ=1.064 um) at 0x304c99a90>,
#  <OpticalNode MC2.p2.o @ 0x3040b6f90>: <BeamParam (w0=2.1254 mm, w=3.3776 mm, z=-16.473 m, nr=1, λ=1.064 um) at 0x304c9aae0>,
#  <OpticalNode MC3.p1.i @ 0x3040d0bf0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c9b2f0>,
#  <OpticalNode MC3.p3.o @ 0x3040d0fb0>: <BeamParam (w0=2.1254 mm, w=2.1257 mm, z=-232.5 mm, nr=1, λ=1.064 um) at 0x304c99b20>,
# ...

# %%
lho.MC3
# Out:
# <'MC3' @ 0x3040d03e0 (Beamsplitter)>

# %%
lho.MC3.parameters
# Out:
# [<MC3.misaligned=False @ 0x3040e1000>,
#  <MC3.plane=0 @ 0x3040e10c0>,
#  <MC3.ybeta=0.0 @ 0x3040e1180>,
#  <MC3.xbeta=0.0 @ 0x3040e1240>,
#  <MC3.Rcy=inf @ 0x3040e1300>,
#  <MC3.Rcx=inf @ 0x3040e13c0>,
#  <MC3.alpha=44.59 @ 0x3040e1480>,
#  <MC3.phi=0.0 @ 0x3040e1540>,
#  <MC3.L=2e-05 @ 0x3040e1600>,
#  <MC3.T=0.00637 @ 0x3040e16c0>,
#  <MC3.R=0.99361 @ 0x3040e1780>]

# %%
lho.PRM.parameeters
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 lho.PRM.parameeters
#
# AttributeError: 'Mirror' object has no attribute 'parameeters'

# %%
lho.PRM.parameters
# Out:
# [<PRM.misaligned=False @ 0x303e0cac0>,
#  <PRM.ybeta=0.0 @ 0x303e0cb80>,
#  <PRM.xbeta=0.0 @ 0x303e0cc40>,
#  <PRM.Rcy=-10.948 @ 0x303e0cd00>,
#  <PRM.Rcx=-10.948 @ 0x303e0cdc0>,
#  <PRM.phi=(PRCL.DC+(-1.0*MICH2.DC)) @ 0x303e0ce80>,
#  <PRM.L=0.0 @ 0x303e0cf40>,
#  <PRM.T=0.031 @ 0x303e0d000>,
#  <PRM.R=0.969 @ 0x303e0d0c0>]

# %%
lho.PRM.thickness
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 lho.PRM.thickness
#
# AttributeError: 'Mirror' object has no attribute 'thickness'
